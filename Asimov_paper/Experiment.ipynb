# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator
from scipy.stats import norm
from scipy.stats import chi2
from scipy.stats import ncx2
from scipy.stats import poisson
from ipywidgets import interact, interactive, fixed, interact_manual
# %matplotlib inline

# %% [markdown]
# ## Background

# %%
def bkgr_func(x, a, exp):
    y = a * np.exp(-x/exp)
    return y

# %%
a = 500
exp = 500

# %%
x_range = np.linspace(0, 1000, 101)

# %%
bkgr_ideal = bkgr_func(x_range, a, exp)

# %%
plt.plot(x_range, bkgr_ideal)

# %%
bkgr_real = np.asarray([poisson.rvs(mu=bin_lambda) for bin_lambda in  bkgr_ideal])

# %%
plt.plot(x_range, bkgr_real);

# %% [markdown]
# ## Signal

# %%
def sig_func(x, mag, mean, sigma):
    y = mag*norm.pdf(x, mean, sigma)
    return y

# %%
mag = 1e4
mean = 500.0
sigma = 50

# %%
sig_ideal = sig_func(x_range, mag, mean, sigma)

# %%
plt.plot(x_range, sig_ideal)

# %%
sig_real = np.asarray([poisson.rvs(mu=bin_lambda) for bin_lambda in  sig_ideal])

# %%
plt.plot(x_range, sig_real);

# %% [markdown]
# ## Data

# %%
data_observed = bkgr_real + sig_real

# %%
plt.plot(x_range, data_observed);
